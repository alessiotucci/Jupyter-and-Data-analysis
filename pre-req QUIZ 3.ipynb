# %% [markdown]
# # QUIZ 3 - TOPIC 6 PREP
# ## Launch Jupyter Notebook
#
# ```powershell
# cd %USERPROFILE%\Documents
# jupyter notebook
# ```

# %% [markdown]
# Jupyter Notebook should open automatically in your web browser.
#
# ## Create a New Notebook
#
# * Select New → Python 3 (ipykernel)
#
# * Select File → Save Notebook

# %% [markdown]
# ## 1) Verify Core Python Libraries
# Create a new cell and run:
# ```python
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```

# %%
# write the code here and verify

# %% [markdown]
# ## 2) Load an Excel File
#
# Upload or copy: `file_name.xlsx` into the same folder as the notebook.
# Run:
#
# ```python
# import pandas as pd
# df = pd.read_excel("file_name.xlsx")
# ```

# %%
# write the code and verify

# %% [markdown]
# ### **Common Issue**: FileNotFoundError: Airbnb.xlsx
#
# Check current folder:
#
# ```python
# import os
# print(os.getcwd())
# print(sys.executable)
# ```

# %%
# write the code and verify

# %% [markdown]
# ## One-time Setup (per computer)
#
# Install ydata_profiling
#
# ```python
# %pip install ydata_profiling==4.12.2 "setuptools<70"
# ```

# %%
# write the code and verify

# %% [markdown]
# If `%pip` is not recognised, try:
#
# ```python
# !pip install ydata_profiling==4.12.2 "setuptools<70"
# ```
#
# After installation:
#
# * Kernel → Restart Kernel
#
# Verify installation:
#
# ```python
# import ydata_profiling
# print(ydata_profiling._version_)
# ```
#
# Expected output: 4.12.2

# %%
# write the code and verify

# %% [markdown]
# ## 3. Generate a Profile Report
#
# ```python
# from ydata_profiling import Profile Report
# profile = ProfileReport(df)
# ```

# %%
# write the code and verify

# %% [markdown]
# Save the report:
#
# ```python
# profile.to_file("fine_name_Profile_Report.html")
# ```

# %%
# write the code and verify

# %% [markdown]
# ## Topic 7: sklearn
#
# Run:
#
# ```python
# import sklearn
# print(sklearn._version_)
# ```
#
# Expected output: 1.5.1 (or a similar version number)
# This confirms: Scikit-learn installed

# %%
# write the code and verify

# %% [markdown]
# ## Assessment 1 Readiness Checklist
#
# | Test                    | Status |
# | ----------------------- | ------ |
# | Launch Jupyter Notebook | A      |
# | Create and save notebook |  |
# | Load Excel file |  |
# | pandas |  |
# | numpy |  |
# | seaborn |  |
# | matplotlib |  |
# | ydata_profiling |  |
# | scikit-learn |  |
